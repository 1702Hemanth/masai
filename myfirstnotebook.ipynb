# %%
print("helllo")
# Out:
# helllo

# %% [markdown]
# HARDWARE
#
# Hardware refers to the physical parts of a computer that you can see and touch.
#
# It includes devices like keyboard, mouse, monitor, CPU, etc.
#
# 👉 Example: Keyboard
#
# -------------------------------------------------------------------------------
# SOFTWARE
#
# Software refers to the programs and instructions that tell the hardware what to do.
#
# It cannot be touched physically.
#
# 👉 Example: Windows Operating System
